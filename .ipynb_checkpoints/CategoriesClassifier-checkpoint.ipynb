# %% [markdown]
# # Capptu Categories Approach to createMl model
#
#      ## Results from createml
#
#
#
#     ******CONFUSION MATRIX******
#     ----------------------------------
#     True\Pred                    Animales_y_mascotas Arquitectura_y_Edificios Comida_y_Bebidas Deportes_y_Acondicionamiento  Naturaleza  Transportes
#     Animales_y_mascotas          1615                41                       53               15                            191         13
#     Arquitectura_y_Edificios     27                  1543                     49               60                            192         82
#     Comida_y_Bebidas             36                  55                       1697             28                            62          19
#     Deportes_y_Acondicionamiento 101                 340                      158              775                           340         171
#     Naturaleza                   125                 169                      60               71                            1485        51
#     Transportes                  44                  286                      60               158                           226         1135
#
#     ******PRECISION RECALL******
#     ----------------------------------
#     Class                        Precision(%)   Recall(%)
#     Animales_y_mascotas          82.91          83.77
#     Arquitectura_y_Edificios     63.39          79.01
#     Comida_y_Bebidas             81.70          89.46
#     Deportes_y_Acondicionamiento 70.01          41.11
#     Naturaleza                   59.50          75.73
#     Transportes                  77.16          59.46
#
#
#
#     ----------------------------------
#     Number of examples: 11533
#     Number of classes: 6
#     Accuracy: 71.53%

# %%
import os 
import sys
import keras
from PIL import  Image
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D
from keras.models import  Model, Sequential
from keras.optimizers import Adam
from __future__ import print_function
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.applications.resnet50 import ResNet50
# Out:
# Using TensorFlow backend.

# %%
"""Defining image generators"""

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, images_path, batch_size_per_class=32, dim=(256,256), n_classes=6, data_augm=False):
        category_images = dict()
        categories = os.listdir(images_path)
        mean_image = cv2.resize(cv2.imread('./mean_image.jpg'), )
        clases = {'Naturaleza':0,
         'Deportes_y_Acondicionamiento':1,
         'Transportes':2,
         'Animales_y_mascotas':3,
         'Arquitectura_y_Edificios':4,
         'Comida_y_Bebidas':5}
        for x in categories:
            images = os.listdir( images_path + x ) 
            category_images [x]  = images
        self.data_augm = data_augm
        self.clases =  clases
        self.images_path = images_path
        self.dim = dim
        self.batch_size = batch_size_per_class
        self.n_classes = n_classes
        self.category_images = category_images
        self.mean_image = mean_image
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return 10
    

    def __getitem__(self, index):
        chosen = dict()
        for category in self.category_images.keys():
            random.shuffle(self.category_images[category])
            chosen [category] = self.category_images[category][: self.batch_size]
        # Generate data
        X, y = self.__data_generation(chosen)
        return np.array(X), to_categorical(y)
    
    def on_epoch_end(self):
        """Nothing"""

    def __data_generation(self, chosen):
        x = []
        y = []
        angles = [0,90,180,270]
        categories = chosen.keys()
        for category in chosen.keys():
            for image_name in chosen[category]:
#                 im = Image.open( self.images_path +category+'/'+image_name)
                image = cv2.resize(cv2.imread(self.images_path +category + '/' + image_name),(128,128)) - self.mean_image
                if self.data_augm is True:
                    (h,w,ch) = image.shape
                    center = (w/2, h/2)
                    r = np.random.randint(0,4)
                    f = np.random.randint(0,2)
                    M=cv2.getRotationMatrix2D(center, angles[r], 1)
                    image = cv2.warpAffine(image,M,(h,w))
                    image = cv2.flip(image,f)
                    if random.random() > .5:
                        kernel = np.ones((5,5),np.float32)/25
                        image = cv2.filter2D(image,-1,kernel)
                x.append(image)
                y.append(self.clases[category])
        return x, y
train_generator = DataGenerator(images_path='./train/', batch_size_per_class=6, data_augm=True) # 6 classes -> 36 photos per batch
test_generator = DataGenerator(images_path='./test/', batch_size_per_class=4, data_augm=False)

# %%
train_generator.__getitem__(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3f389a2bcf09> in <module>()
# ----> 1 train_generator.__getitem__(0)
#
# <ipython-input-2-3259ffaf0d35> in __getitem__(self, index)
#      37             chosen [category] = self.category_images[category][: self.batch_size]
#      38         # Generate data
# ---> 39         X, y = self.__data_generation(chosen)
#      40         return np.array(X), to_categorical(y)
#      41
#
# <ipython-input-2-3259ffaf0d35> in __data_generation(self, chosen)
#      51             for image_name in chosen[category]:
#      52 #                 im = Image.open( self.images_path +category+'/'+image_name)
# ---> 53                 image = cv2.resize(cv2.imread(self.images_path +category + '/' + image_name),(128,128)) - self.mean_image
#      54                 if self.data_augm is True:
#      55                     (h,w,ch) = image.shape
#
# ValueError: operands could not be broadcast together with shapes (128,128,3) (244,244,3)

# %%
x,y = train_generator.__getitem__(1)
for i in x:
    plt.imshow(i)
    plt.show()

# %%
#create model
# model = Sequential()#add model layers
# model.add(InputLayer(input_shape=(244, 244,3)))
# model.add(Conv2D(8, kernel_size=8, activation='relu'))
# model.add(Conv2D(16, kernel_size=8, activation='relu'))
# model.add(Flatten())
# model.add(Dense(6, activation='softmax'))
# adam = Adam(lr=0.001, decay=0.00000001, amsgrad=False)
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics= ['mae'])
# model.summary()

# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3),
#                  activation='relu',
#                  input_shape=(244,244,3)))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(6, activation='softmax'))
# model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
# model.summary()

def m_1():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(244, 244, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6), activation='softmax')
    model.add(Activation('sigmoid'))

    model.compile(loss=binary_crossentropy,
                  optimizer=RMSprop(lr=0.0005),  # half of the default lr
                  metrics=['accuracy'])

def m_0(core_model_trainable_layers = 2):
    inp = Input(shape=(244, 244, 3))
    x = MobileNetV2(weights='imagenet', include_top=True)(inp)
    x = Dropout(.5)(x)
    x = Dense(100, activation='softmax')(x)
    x = Dropout(.5)(x)
    x = Dense(6, activation='softmax')(x)
    
    model = Model(inp, x)
    adam = Adam(lr=0.001, decay=0.00000001, amsgrad=False)
    l_lenght = len(model.layers[1].layers)
    for i, layer in enumerate(model.layers[1].layers):#[:-core_model_trainable_layers]:
        if i < l_lenght - core_model_trainable_layers:
            layer.trainable = False
        else:
            layer.trainable = True
    model.compile(loss='mean_squared_error', optimizer='adam', metrics= ['mae', 'acc'])
    return model

# %%
model = m_0()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 244, 244, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Model) (None, 1000)              3538984
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               100100
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 606
# =================================================================
# Total params: 3,639,690
# Trainable params: 1,381,706
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
history = model.fit_generator(generator=train_generator, validation_data=test_generator, steps_per_epoch=1588, validation_steps=400, epochs=100)
# Out:
# Epoch 1/100
# 1588/1588 [==============================] - 282s 177ms/step - loss: 0.1362 - mean_absolute_error: 0.2740 - acc: 0.2209 - val_loss: 0.1303 - val_mean_absolute_error: 0.2673 - val_acc: 0.3701
# Epoch 2/100
# 1588/1588 [==============================] - 271s 171ms/step - loss: 0.1315 - mean_absolute_error: 0.2658 - acc: 0.2702 - val_loss: 0.1238 - val_mean_absolute_error: 0.2579 - val_acc: 0.4069
# Epoch 3/100
# 1588/1588 [==============================] - 279s 175ms/step - loss: 0.1293 - mean_absolute_error: 0.2609 - acc: 0.2818 - val_loss: 0.1190 - val_mean_absolute_error: 0.2514 - val_acc: 0.4517
# Epoch 4/100
# 1588/1588 [==============================] - 279s 176ms/step - loss: 0.1275 - mean_absolute_error: 0.2569 - acc: 0.2972 - val_loss: 0.1162 - val_mean_absolute_error: 0.2463 - val_acc: 0.4552
# Epoch 5/100
# 1588/1588 [==============================] - 272s 171ms/step - loss: 0.1262 - mean_absolute_error: 0.2538 - acc: 0.3040 - val_loss: 0.1140 - val_mean_absolute_error: 0.2432 - val_acc: 0.4692
# Epoch 6/100
# 1588/1588 [==============================] - 270s 170ms/step - loss: 0.1252 - mean_absolute_error: 0.2516 - acc: 0.3096 - val_loss: 0.1122 - val_mean_absolute_error: 0.2401 - val_acc: 0.4766
# Epoch 7/100
# 1588/1588 [==============================] - 267s 168ms/step - loss: 0.1250 - mean_absolute_error: 0.2507 - acc: 0.3142 - val_loss: 0.1134 - val_mean_absolute_error: 0.2416 - val_acc: 0.4653
# Epoch 8/100
# 1588/1588 [==============================] - 267s 168ms/step - loss: 0.1246 - mean_absolute_error: 0.2495 - acc: 0.3137 - val_loss: 0.1137 - val_mean_absolute_error: 0.2429 - val_acc: 0.4690
# Epoch 9/100
# 1588/1588 [==============================] - 271s 171ms/step - loss: 0.1241 - mean_absolute_error: 0.2491 - acc: 0.3178 - val_loss: 0.1127 - val_mean_absolute_error: 0.2412 - val_acc: 0.4754
# Epoch 10/100
# 1588/1588 [==============================] - 274s 173ms/step - loss: 0.1238 - mean_absolute_error: 0.2483 - acc: 0.3207 - val_loss: 0.1138 - val_mean_absolute_error: 0.2432 - val_acc: 0.4479
# Epoch 11/100
# 1588/1588 [==============================] - 261s 164ms/step - loss: 0.1229 - mean_absolute_error: 0.2470 - acc: 0.3343 - val_loss: 0.1116 - val_mean_absolute_error: 0.2401 - val_acc: 0.5118
# Epoch 12/100
# 1588/1588 [==============================] - 266s 167ms/step - loss: 0.1224 - mean_absolute_error: 0.2456 - acc: 0.3452 - val_loss: 0.1117 - val_mean_absolute_error: 0.2402 - val_acc: 0.4914
# Epoch 13/100
# 1588/1588 [==============================] - 274s 173ms/step - loss: 0.1213 - mean_absolute_error: 0.2437 - acc: 0.3525 - val_loss: 0.1104 - val_mean_absolute_error: 0.2386 - val_acc: 0.4986
# Epoch 14/100
# 1588/1588 [==============================] - 282s 177ms/step - loss: 0.1202 - mean_absolute_error: 0.2411 - acc: 0.3598 - val_loss: 0.1096 - val_mean_absolute_error: 0.2370 - val_acc: 0.5113
# Epoch 15/100
# 1588/1588 [==============================] - 272s 171ms/step - loss: 0.1200 - mean_absolute_error: 0.2403 - acc: 0.3629 - val_loss: 0.1097 - val_mean_absolute_error: 0.2381 - val_acc: 0.5140
# Epoch 16/100
# 1588/1588 [==============================] - 281s 177ms/step - loss: 0.1200 - mean_absolute_error: 0.2400 - acc: 0.3626 - val_loss: 0.1103 - val_mean_absolute_error: 0.2385 - val_acc: 0.5338
# Epoch 17/100
# 1588/1588 [==============================] - 274s 172ms/step - loss: 0.1194 - mean_absolute_error: 0.2388 - acc: 0.3657 - val_loss: 0.1099 - val_mean_absolute_error: 0.2380 - val_acc: 0.5075
# Epoch 18/100
# 1588/1588 [==============================] - 272s 172ms/step - loss: 0.1187 - mean_absolute_error: 0.2376 - acc: 0.3701 - val_loss: 0.1074 - val_mean_absolute_error: 0.2339 - val_acc: 0.5190
# Epoch 19/100
# 1588/1588 [==============================] - 284s 179ms/step - loss: 0.1185 - mean_absolute_error: 0.2370 - acc: 0.3712 - val_loss: 0.1082 - val_mean_absolute_error: 0.2353 - val_acc: 0.5254
# Epoch 20/100
# 1588/1588 [==============================] - 267s 168ms/step - loss: 0.1183 - mean_absolute_error: 0.2368 - acc: 0.3727 - val_loss: 0.1097 - val_mean_absolute_error: 0.2378 - val_acc: 0.5227
# Epoch 21/100
# 1588/1588 [==============================] - 264s 166ms/step - loss: 0.1176 - mean_absolute_error: 0.2357 - acc: 0.3856 - val_loss: 0.1064 - val_mean_absolute_error: 0.2320 - val_acc: 0.5573
# Epoch 22/100
# 1588/1588 [==============================] - 265s 167ms/step - loss: 0.1171 - mean_absolute_error: 0.2345 - acc: 0.3959 - val_loss: 0.1045 - val_mean_absolute_error: 0.2297 - val_acc: 0.5878
# Epoch 23/100
# 1588/1588 [==============================] - 262s 165ms/step - loss: 0.1163 - mean_absolute_error: 0.2329 - acc: 0.4017 - val_loss: 0.1038 - val_mean_absolute_error: 0.2273 - val_acc: 0.5891
# Epoch 24/100
# 1588/1588 [==============================] - 270s 170ms/step - loss: 0.1148 - mean_absolute_error: 0.2301 - acc: 0.4150 - val_loss: 0.1031 - val_mean_absolute_error: 0.2257 - val_acc: 0.5789
# Epoch 25/100
# 1588/1588 [==============================] - 264s 166ms/step - loss: 0.1144 - mean_absolute_error: 0.2286 - acc: 0.4167 - val_loss: 0.1024 - val_mean_absolute_error: 0.2265 - val_acc: 0.5829
# Epoch 26/100
# 1588/1588 [==============================] - 266s 168ms/step - loss: 0.1142 - mean_absolute_error: 0.2286 - acc: 0.4193 - val_loss: 0.1028 - val_mean_absolute_error: 0.2256 - val_acc: 0.5785
# Epoch 27/100
# 1588/1588 [==============================] - 266s 168ms/step - loss: 0.1138 - mean_absolute_error: 0.2275 - acc: 0.4211 - val_loss: 0.1022 - val_mean_absolute_error: 0.2248 - val_acc: 0.5794
# Epoch 28/100
# 1588/1588 [==============================] - 263s 165ms/step - loss: 0.1131 - mean_absolute_error: 0.2264 - acc: 0.4256 - val_loss: 0.1005 - val_mean_absolute_error: 0.2218 - val_acc: 0.5903
# Epoch 29/100
# 1588/1588 [==============================] - 267s 168ms/step - loss: 0.1127 - mean_absolute_error: 0.2253 - acc: 0.4283 - val_loss: 0.1010 - val_mean_absolute_error: 0.2228 - val_acc: 0.5904
# Epoch 30/100
# 1588/1588 [==============================] - 270s 170ms/step - loss: 0.1124 - mean_absolute_error: 0.2244 - acc: 0.4278 - val_loss: 0.1030 - val_mean_absolute_error: 0.2248 - val_acc: 0.5683
# Epoch 31/100
# 1588/1588 [==============================] - 273s 172ms/step - loss: 0.1118 - mean_absolute_error: 0.2236 - acc: 0.4334 - val_loss: 0.1010 - val_mean_absolute_error: 0.2200 - val_acc: 0.5918
# Epoch 32/100
# 1588/1588 [==============================] - 277s 175ms/step - loss: 0.1116 - mean_absolute_error: 0.2230 - acc: 0.4337 - val_loss: 0.1011 - val_mean_absolute_error: 0.2193 - val_acc: 0.5818
# Epoch 33/100
# 1588/1588 [==============================] - 276s 174ms/step - loss: 0.1118 - mean_absolute_error: 0.2230 - acc: 0.4325 - val_loss: 0.1014 - val_mean_absolute_error: 0.2199 - val_acc: 0.5744
# Epoch 34/100
# 1588/1588 [==============================] - 269s 169ms/step - loss: 0.1106 - mean_absolute_error: 0.2210 - acc: 0.4412 - val_loss: 0.1008 - val_mean_absolute_error: 0.2152 - val_acc: 0.5859
# Epoch 35/100
# 1588/1588 [==============================] - 271s 171ms/step - loss: 0.1105 - mean_absolute_error: 0.2205 - acc: 0.4421 - val_loss: 0.0975 - val_mean_absolute_error: 0.2150 - val_acc: 0.6122
# Epoch 36/100
# 1588/1588 [==============================] - 270s 170ms/step - loss: 0.1106 - mean_absolute_error: 0.2206 - acc: 0.4441 - val_loss: 0.1005 - val_mean_absolute_error: 0.2188 - val_acc: 0.5886
# Epoch 37/100
# 1588/1588 [==============================] - 252s 159ms/step - loss: 0.1106 - mean_absolute_error: 0.2206 - acc: 0.4398 - val_loss: 0.0995 - val_mean_absolute_error: 0.2149 - val_acc: 0.5835
# Epoch 38/100
# 1588/1588 [==============================] - 257s 162ms/step - loss: 0.1103 - mean_absolute_error: 0.2198 - acc: 0.4429 - val_loss: 0.0997 - val_mean_absolute_error: 0.2164 - val_acc: 0.5906
# Epoch 39/100
#  211/1588 [==>...........................] - ETA: 3:24 - loss: 0.1097 - mean_absolute_error: 0.2194 - acc: 0.4423

# %%
plt.plot(model.history.history['val_acc'])

# %% [markdown]
#     # to resize images
#     # import os
#     # from PIL import Image
#     # import sys
#     # def resize():
#     #     origin_path = './filtered_categories/'
#     #     destination_path = './filtered_categories_resized/'
#     #     cats = os.listdir(origin_path)
#     #     for cat in cats:
#     #         os.system('rm -rv ' + destination_path + cat)
#     #         os.system('mkdir ' + destination_path + cat)
#
#     #     for cat in cats:
#     #         print cat
#     #         for im_name in os.listdir(origin_path + cat):
#     #             try:
#     #                 im = Image.open(origin_path + cat + '/' + im_name).resize((512,512))
#     #                 im.save(destination_path + cat + '/' + im_name)
#     #                 print cat, im_name
#     #             except:
#     #                 print "                       Error" + im_name
#     # resize()
#
#
#     # import os
#     # import sys
#     # import random
#     # def move():
#     #     origin_path = './filtered_categories_resized/'
#     #     destination_path = './filtered_categories_resized_test/'
#     #     cats = os.listdir(origin_path)
#
#     #     for cat in cats:
#     #         os.system('mkdir ' + destination_path + cat)
#
#     #     for cat in cats:
#     #         print cat
#     #         files = os.listdir(origin_path + cat)
#
#     #         files_to_move = int(.2 * len(files))
#
#     #         random.shuffle(files)
#     #         for im_name in files[:files_to_move]:
#     #             os.system('mv ' + origin_path + cat + '/' + im_name + ' '+destination_path+ cat+ '/' + im_name )
#
#     # move()
#
#
#
#
#     # Partition Data
#     # import os
#     # import sys
#     # import random
#     # def move():
#     #     origin_path = './filtered_categories_resized/'
#     #     destination_path = './filtered_categories_resized_test/'
#     #     cats = os.listdir(origin_path)
#
#     #     for cat in cats:
#     #         os.system('mkdir ' + destination_path + cat)
#
#     #     for cat in cats:
#     #         print cat
#     #         files = os.listdir(origin_path + cat)
#
#     #         files_to_move = int(.2 * len(files))
#
#     #         random.shuffle(files)
#     #         for im_name in files[:files_to_move]:
#     #             os.system('mv ' + origin_path + cat + '/' + im_name + ' '+destination_path+ cat+ '/' + im_name )
